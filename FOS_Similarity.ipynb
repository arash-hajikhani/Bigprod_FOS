# %% [markdown]
# # FOS Similarity
#
# This notebook contains instructions how to obtain similarities between FOS'es

# %%
import pickle 
import json
from sklearn.metrics.pairwise import cosine_similarity

# %% [markdown]
# ### Load Dependencies
#
# Download the following zip file which contains the dependencies needed for proceeding the next steps: https://drive.google.com/file/d/1QtYXkXXfYUgooj_00OQJI4GFfR6kfnQ0/view?usp=sharing

# %%
#Load the three files download previously
# Mapping between FOS IDs and Names
with open("FOSMAP.json") as file :
    fos_map = json.loads(file.read()) #Map the fos ids to the fos names
    
#Mapping between FOS ID and its row number in the matrix
with open("FOSIndex.json") as file :
    fos_index = json.loads(file.read()) #perform an indexing on the fos ids
    
fos_index2 = {item:index for index, item in enumerate(fos_index)}

#FOS TF-IDF vector matrix
with open("CombinedNGRAMMatrixCSR.pkl", "rb") as file :
    fos_matrix = pickle.load(file)

# %% [markdown]
# ### Define similarity function

# %%
def get_similarity_scores( fos_id ):
    """
    Function to get top 100 most similar FOS'es to a given FOS ID
    PARAMS
    fos_id (string) FOS ID
    
    RETURNS
    list of tuples [(fos_id, similarity score)]
    """
    
    # Take a row from FOS matrix 
    fos_row = fos_matrix.getrow( fos_index2[fos_id] )
    
    #Calculate similarity between the row and matrix
    fos_result_mat = cosine_similarity( fos_matrix, Y = fos_row , dense_output=True )
    
    #Convert result vector to dict
    fos_result_raw = [ (x,i[0]) for x,i in enumerate( fos_result_mat ) ]

    #Sort Select TOP 100 FOS
    fos_final_result = [ (fos_index[ i[0] ] , i[1]) for i in sorted( fos_result_raw , key = lambda kv : kv[1] ,reverse = True )[0:100] ]
    
    return fos_final_result

# %% [markdown]
# ### This section can get a fos id and give the most similar fos'es to the given fos id.

# %%
fos_map["2779652045"]
# Out:
# 'Pharmaceutical industry'

# %%
#recives the fos id and gives the top five similar fos'es
similar_fos = get_similarity_scores( "2779652045" )

similar_fos[0:5]
# Out:
# [('2779652045', 1.0000000000000018),
#  ('178855305', 0.7003413520864034),
#  ('2909735440', 0.6761556891037742),
#  ('2779535233', 0.661582139881108),
#  ('2781419290', 0.6511705997499511)]

# %%
#fos names can be mached to the fos ids
for item in similar_fos[0:10]:
    print( fos_map[item[0]])
# Out:
# Pharmaceutical industry
# Pharmaceutical sciences
# Drug marketing
# Pharmaceutical drug
# Pharmaceutical marketing
# Drug Company
# Drug development
# Drug pipeline
# New chemical entity
# Pharmaceutical policy

# %% [markdown]
# ### This section will get rang of fos ids and give the similarity between them in an adjacency matrix

# %%
from scipy.sparse import vstack

def get_similarity_scores_v3( fos_ids ):
    """
    Function to get similarity scores to given list of FOS IDs
    PARAMS
    fos_ids (list of strings)[fos_id] FOS IDs
   
    RETURNS
    array 153247 x len(fos_ids)
    """
    fos_rows = []
    # Take a row from FOS matrix
    for fos_id in fos_ids :
        fos_row = fos_matrix.getrow( fos_index2[fos_id] )
        fos_rows.append( fos_row )
   
    fos_mat = vstack( fos_rows )
   
    #Calculate similarity between the row and matrix
    fos_result_mat = cosine_similarity( fos_mat , dense_output=True )
   
   
    return fos_result_mat

# %%
#for example five fos ids are given and the result is showing the fos similarities.
similar_fos = get_similarity_scores_v3 (["178855305", "2779652045", "2909735440", "2779535233", "2781419290"])

similar_fos
# Out:
# array([[1.        , 0.70034135, 0.62248533, 0.86785788, 0.61750199],
#        [0.70034135, 1.        , 0.67615569, 0.66158214, 0.6511706 ],
#        [0.62248533, 0.67615569, 1.        , 0.73287974, 0.67798056],
#        [0.86785788, 0.66158214, 0.73287974, 1.        , 0.59640948],
#        [0.61750199, 0.6511706 , 0.67798056, 0.59640948, 1.        ]])

# %% [markdown]
# ### Annex: Input data types/shape

# %%
fos_map
# Out:
# {'1443462': 'Immobiliser',
#  '1576492': 'Matrix pencil',
#  '2657588': 'Combinatorial topology',
#  '3079626': 'Quantum electrodynamics',
#  '3535393': 'Mesophase',
#  '5688416': 'Neutron cross section',
#  '7271767': 'Primer (molecular biology)',
#  '10389098': 'Batch file',
#  '11045955': 'ElGamal encryption',
#  '12404463': 'Chemical industry',
#  '13818915': '2–3 tree',
#  '14981831': 'Market clearing',
#  '16287357': 'U.S. Standard Atmosphere',
#  '19044487': 'Control zone',
#  '19159745': 'Social policy',
#  '19513336': 'Snapshot isolation',
#  '20137635': 'Bionomics',
#  '20692236': 'Algorism',
#  '22081632': "Turán's inequalities",
#  '22664368': 'Oracle Unified Method',
#  '24914591': 'Specific force',
#  '24992206': 'Roadway noise',
#  '26268613': 'Cell disruption',
#  '30658544': 'Mobile collaboration',
#  '31571166': 'Picard horn',
#  '33107880': 'Retarder',
#  '33341308': 'Terminal node controller',
#  '33493656': 'Elliott–Halberstam conjecture',
#  '35294091': 'Loading dose',
#  '37914503': 'Mathematical physics',
#  '39078644': 'Isovolumetric contraction',
#  '41484392': 'Arago spot',
#  '42199009': 'Data cleansing',
#  '45462083': 'Documentation science',
#  '46097333': 'Disruptive selection',
#  '48981059': 'Zugunruhe',
#  '51450119': 'iRobot Seaglider',
#  '51807945': 'Electroplating',
#  '54281923': 'Displacement (vector)',
#  '55457006': 'Kinesthetic learning',
#  '55743289': 'Laser guide star',
#  '57130246': 'Broadside',
#  '57736034': 'Molecular diffusion',
#  '57997129': 'Drafting machine',
#  '58217581': 'Session layer',
#  '60760409': 'Dye laser',
#  '61997241': 'Care perspective',
#  '63504599': 'Economic globalization',
#  '64103335': 'Doorway page',
#  '65487801': 'Growling',
#  '73529369': 'Causal theory of knowledge',
#  '73758832': 'Splicing factor',
#  '73782692': 'Random error',
#  '75323523': 'Giant retinal ganglion cells',
#  '75866337': 'Radial basis function kernel',
#  '75877943': 'CXCL13',
#  '75988497': 'Monster group',
#  '76713136': 'Curb weight',
#  '78945076': 'Herbarium',
#  '79061980': 'Inertial measurement unit',
#  '79877727': 'WRKY protein domain',
#  '80621561': 'Operant conditioning chamber',
#  '80994870': 'Stokes shift',
#  '83199326': 'Acoustic levitation',
#  '83487572': 'Space–time block code',
#  '86038547': 'Particle displacement',
#  '87225262': 'Phantom power',
#  '87626647': 'IEEE 802.1AE',
#  '89448510': 'Dielectric barrier discharge',
#  '91066073': 'Dielectric loss',
#  '94898600': 'Flat panel detector',
#  '95392273': 'Fully qualified domain name',
#  '96224696': 'Proportional control',
#  '98440294': 'Bethe formula',
#  '101676477': 'Remand (detention)',
#  '101901036': 'Semidefinite programming',
#  '105525253': 'Methanizer',
#  '107553311': 'Comet (programming)',
#  '108812129': 'Anti-Zionism',
#  '110332635': 'Genetic programming',
#  '110342517': 'Constant coefficients',
#  '113308832': 'Biceps reflex',
#  '114265396': 'Brood',
#  '116592611': 'Metabotropic glutamate receptor 4',
#  '117009084': 'Facility management',
#  '117262203': 'Board foot',
#  '117283582': 'Cornering force',
#  '117774814': 'Electronic media',
#  '120241979': 'Einselection',
#  '120923412': 'Prefoldin',
#  '120958224': 'Periodization',
#  '121285527': 'Buffered oxide etch',
#  '124015408': 'Law of the land',
#  '126148662': 'Discretization error',
#  '126314574': 'Air quality index',
#  '128194758': 'Development anthropology',
#  '129206188': 'Faraday rotator',
#  '130453509': 'Stylobate',
#  '133377346': 'Lipophilic efficiency',
#  '134503902': 'Information technology management',
#  '135255052': 'Dolby E',
#  '135653721': 'Instructions per second',
#  '135736735': 'Space physics',
#  '138154225': 'Elementary event',
#  '138512509': "Rolle's theorem",
#  '139563560': 'Natural killer T cell',
#  '139876678': 'Production function',
#  '140461892': 'Loop counter',
#  '141055242': 'Molecular solid',
#  '147192597': 'Ionization energy',
#  '147640893': 'Quasi-analytic function',
#  '148012203': 'Pre-determined overhead rate',
#  '151510863': 'Lorenz system',
#  '152233112': 'CEBPB',
#  '155330019': 'RNA-induced silencing complex',
#  '155878204': 'K-server problem',
#  '156602925': 'Tropical marine climate',
#  '156812175': 'Organizational architecture',
#  '159047783': 'Virology',
#  '163419389': 'A priori probability',
#  '164731562': 'Higgs mechanism',
#  '165617652': 'Nested case-control study',
#  '166126730': 'Planck',
#  '167310288': 'Sound quality',
#  '168020605': 'Blue straggler',
#  '171089853': 'Online search',
#  '172268261': 'Animal studies',
#  '173890291': 'Patronymic',
#  '176181172': 'Nondeterministic algorithm',
#  '176524297': 'Active transport',
#  '176656743': 'Serving size',
#  '177551703': 'Hemicontinuity',
#  '177866494': 'Localizer performance with vertical guidance',
#  '178325634': 'Lenstra elliptic curve factorization',
#  '178557918': 'Polarization mode dispersion',
#  '180500224': 'File Control Block',
#  '181290262': 'Ekistics',
#  '181587685': 'Bejan number',
#  '182207606': 'Geometallurgy',
#  '182620335': 'Answer set programming',
#  '182930780': 'Ecological urbanism',
#  '183906286': 'Material flow',
#  '184125076': 'Classical Hamiltonian quaternions',
#  '186569918': 'Neofunctionalism',
#  '188598960': 'Test strategy',
#  '188873839': 'Demand paging',
#  '193307473': 'Neume',
#  '194241460': 'Processing',
#  '195267511': 'Ciliogenesis',
#  '195813598': 'Stakeholder analysis',
#  '198704716': 'Herbig–Haro object',
#  '202472598': 'Case hardening of rocks',
#  '206643129': 'Turbopause',
#  '513476851': 'Dopamine',
#  '515488857': 'Financial cryptography',
#  '516372188': 'Neptunium',
#  '524769229': '3D printing',
#  '543223122': 'Spiritualism',
#  '550656013': 'Weather modification',
#  '2775878893': 'Organic fertilizer',
#  '2775885016': 'King crab',
#  '2775888743': 'Cataract surgery',
#  '2775907427': 'Orthogonal frequency-division multiple access',
#  '2775912189': 'Flatpack',
#  '2775938904': 'Morphea',
#  '2775997378': 'Grindelia',
#  '2776020510': 'Monod equation',
#  '2776040956': 'Iodine monobromide',
#  '2776043724': 'Dicrocoelium dendriticum',
#  '2776043785': 'Sitaxentan',
#  '2776061162': 'Ornaments',
#  '2776076120': 'Nickel selenide',
#  '2776194327': 'Basal dendrite',
#  '2776194824': 'Urea phosphate',
#  '2776257225': 'Uranium-232',
#  '2776279322': 'Surface ectoderm',
#  '2776324051': 'Neopragmatism',
#  '2776400185': 'Bordetella parapertussis',
#  '2776417830': 'Methimazole',
#  '2776428424': 'Schiff base',
#  '2776429440': 'Intractable pain',
#  '2776435075': 'Harmonious Society',
#  '2776456211': 'Hawaiian language',
#  '2776469828': 'Coalbed methane',
#  '2776539142': 'Voice user interface',
#  '2776545201': 'Collaborative leadership',
#  '2776546322': 'Impassibility',
#  '2776551883': 'Enzalutamide',
#  '2776560106': 'Pipeflow',
#  '2776565828': 'Tree inventory',
#  '2776566753': 'Rhipicephalus',
#  '2776598285': 'Endoclip',
#  '2776634448': 'Peptidoglycan',
#  '2776650109': 'Constructivist epistemology',
#  '2776657194': 'Tellina',
#  '2776670229': 'Acute pancreatitis',
#  '2776693535': 'Isobutyl acetate',
#  '2776694393': 'Choroid',
#  '2776715858': 'Hypophosphorous acid',
#  '2776777198': 'Cerebral hypoxia',
#  '2776875504': 'Landscape evolution model',
#  '2776896709': 'Trial of labour',
#  '2776929087': 'Cell-penetrating peptide',
#  '2776939828': 'Net gain',
#  '2776957806': 'Interim',
#  '2776974504': 'Bicultural identity',
#  '2776980937': 'Osteoderm',
#  '2776994406': 'Primary research',
#  '2777039156': 'Stibine',
#  '2777047896': 'Craniopharyngioma',
#  '2777081086': 'Cough medicine',
#  '2777082925': 'Thalassiosira pseudonana',
#  '2777097880': 'Essential hypertension',
#  '2777131951': 'Old Left',
#  '2777154459': 'Heating system',
#  '2777216800': 'Metal injection molding',
#  '2777218816': 'Proliferation Security Initiative',
#  '2777253655': 'Foundational Model of Anatomy',
#  '2777280806': 'Ruegeria',
#  '2777294040': 'Kaede',
#  '2777328239': 'Sarcopenic obesity',
#  '2777328320': 'Tentorium',
#  '2777369524': 'Hydrilla',
#  '2777410594': 'Erythema nodosum',
#  '2777426525': 'Conger',
#  '2777426639': 'Agreed Framework',
#  '2777488010': 'Calpastatin',
#  '2777544329': 'Blattellidae',
#  '2777580761': 'Levobunolol',
#  '2777586496': 'Tetraodontiformes',
#  '2777616060': 'Dichloroacetic acid',
#  '2777620836': 'MCR-1',
#  '2777693409': 'Virosome',
#  '2777705964': 'Hercynite',
#  '2777735388': 'mir-137',
#  '2777741088': 'Allocryptopine',
#  '2777806129': 'Branchinecta',
#  '2777813233': 'Grating',
#  '2777854078': 'Endolymphatic sac tumor',
#  '2777877921': 'Immunolabeling',
#  '2777882243': 'Small intestine',
#  '2777902257': 'Career Pathways',
#  '2777902833': 'Cactoideae',
#  '2777909300': 'Chordeiles',
#  '2777916406': 'Kojibiose',
#  '2777926627': 'Porites porites',
#  '2777930111': 'Nuclear fuel cycle',
#  '2777934238': 'Telomestatin',
#  '2777962424': 'Acanthoscelides obtectus',
#  '2778001298': 'Histone acetyltransferase',
#  '2778001805': 'Mammary gland',
#  '2778155570': 'GALLEX',
#  '2778169546': 'Pecuniary externality',
#  '2778244660': 'Government Office',
#  '2778254743': 'Intercostal nerve block',
#  '2778303017': 'Wide local excision',
#  '2778357643': 'Endostyle',
#  '2778375319': 'Depside',
#  '2778453073': 'Interaction point',
#  '2778503278': 'Navigation function',
#  '2778530908': 'RS Ophiuchi',
#  '2778532505': 'Free convolution',
#  '2778593475': 'Lychnis',
#  '2778605688': 'Freedom of movement',
#  '2778618113': 'Pompano',
#  '2778621876': 'Molgramostim',
#  '2778624327': 'Growth of knowledge',
#  '2778646435': 'Personal network',
#  '2778648096': 'Prostate brachytherapy',
#  '2778649560': 'Limb-girdle muscular dystrophy',
#  '2778666122': 'Anterior interosseous nerve',
#  '2778750487': 'Aortoiliac occlusive disease',
#  '2778763586': 'n-Butyllithium',
#  '2778763703': 'Bit Rate Reduction',
#  '2778786452': 'Sphaeroceridae',
#  '2778801609': 'Uranium tetrafluoride',
#  '2778810951': 'Melvyl',
#  '2778825724': 'Sparrow',
#  '2778827303': 'Soluble guanylyl cyclase',
#  '2778844676': 'Central retinal vein occlusion',
#  '2778899633': 'Sedentary lifestyle',
#  '2778940482': 'Pathfinder',
#  '2778944715': 'Porencephaly',
#  '2779005526': 'Hermetic seal',
#  '2779005926': 'Honeysuckle',
#  '2779009331': 'New Zealand English',
#  '2779024159': 'Lysmata',
#  '2779072137': 'Terminal server',
#  '2779091347': 'Copaifera',
#  '2779134421': 'Paenibacillus polymyxa',
#  '2779147656': 'Dysfunctional uterine bleeding',
#  '2779150434': 'Supply chain optimization',
#  '2779173278': 'Ozonolysis',
#  '2779187253': 'Xanthurenic acid',
#  '2779189161': 'Ammonium hexafluorophosphate',
#  '2779204983': 'Phomopsis',
#  '2779223262': 'Baccharis',
#  '2779271920': 'Electronic article',
#  '2779282603': 'Angular rate sensor',
#  '2779313563': 'On Language',
#  '2779356393': 'Supply-side economics',
#  '2779408833': 'Koro',
#  '2779426729': 'Frequency-locked loop',
#  '2779433023': 'Sedum alfredii',
#  '2779471270': 'Diphyllobothrium',
#  '2779473519': 'Glucono delta-lactone',
#  '2779480814': 'Nandrolone',
#  '2779501447': 'Mast cell leukemia',
#  '2779509574': 'Caste',
#  '2779539726': 'Access token',
#  '2779558830': 'Ordinary Time',
#  '2779625490': 'Systemic scleroderma',
#  '2779625713': 'Hemocyte',
#  '2779643390': 'Folk etymology',
#  '2779669930': 'Upper shoreface',
#  '2779674987': 'Self-acceptance',
#  '2779682186': 'Friend virus',
#  '2779683600': 'Distributed key generation',
#  '2779691516': 'Multi-chip module',
#  '2779699049': 'Herkogamy',
#  '2779699254': 'Recoupment',
#  '2779746291': 'Piceatannol',
#  '2779758070': 'Sticking probability',
#  '2779785285': 'Idose',
#  '2779785697': 'Christian tradition',
#  '2779814568': 'Laminin',
#  '2779854178': 'Panophthalmitis',
#  '2779878498': 'Cockle',
#  '2779885752': 'Legume lectin',
#  '2779898098': 'Intracranial hypertension syndrome',
#  '2779908692': 'Semail Ophiolite',
#  '2779911484': '4-Nitroquinoline 1-oxide',
#  '2779960602': 'Linguistic turn',
#  '2779965144': 'Disposable cup',
#  '2779970790': 'Aluminium sulfate',
#  '2779983348': 'Diastrophic dysplasia',
#  '2780004512': 'Brucella canis',
#  '2780006128': 'Antidesma',
#  '2780038442': 'Poppet valve',
#  '2780065859': 'Feed additive',
#  '2780095022': 'Maltotriose',
#  '2780142257': 'Metropolitan police',
#  '2780150774': 'User profile',
#  '2780158988': 'Centaurus A',
#  '2780236042': 'Fungus gnat',
#  '2780238094': 'HTTP/2',
#  '2780259371': 'Ecklonia stolonifera',
#  '2780286589': 'Microlife',
#  '2780294061': 'Hilbert symbol',
#  '2780306303': 'Folate receptor',
#  '2780308851': 'Proportionalism',
#  '2780345915': 'Backslash',
#  '2780356984': 'Quercus cerris',
#  '2780372667': 'Untranslatability',
#  '2780395675': 'Flank',
#  '2780434117': 'Livedoid vasculitis',
#  '2780439173': 'Trichothecium roseum',
#  '2780447437': 'Dreissenidae',
#  '2780482755': 'Theory-ladenness',
#  '2780519661': 'Curvaton',
#  '2780534490': 'Free-radical addition',
#  '2780554747': 'Longitude',
#  '2780571358': 'Gaeumannomyces',
#  '2780628603': 'Ileal conduit urinary diversion',
#  '2780630512': 'Penicillium expansum',
#  '2780672046': 'First-sale doctrine',
#  '2780676431': 'Widows and orphans',
#  '2780699913': 'Stream power',
#  '2780737243': 'Isogeometric analysis',
#  '2780757810': 'Round window',
#  '2780769633': 'Ethylidene diacetate',
#  '2780805959': 'Tropical theileriosis',
#  '2780836893': 'Fire detection',
#  '2780918503': 'Tetraethylammonium chloride',
#  '2780923370': 'Vibrio natriegens',
#  '2780925005': 'Sicydiinae',
#  '2780961447': 'Double check valve',
#  '2780963105': 'Carboxypeptidase E',
#  '2780978199': 'Paced Auditory Serial Addition Test',
#  '2780995823': 'Potassium tetrachloroplatinate',
#  '2780996845': 'Mesophyllum',
#  '2781028716': 'Channelling',
#  '2781030367': 'Food away from home',
#  '2781057722': 'Acne keloidalis nuchae',
#  '2781099255': 'Hyperammonemia',
#  '2781118382': 'Acyl-CoA-binding protein',
#  '2781128275': 'Reinhardt domain',
#  '2781144357': 'Eisenia fetida',
#  '2781153181': 'Linifanib',
#  '2781154459': 'Zinc ricinoleate',
#  '2781174152': 'Sinigrin',
#  '2781187084': 'Network-centric warfare',
#  '2781205058': 'Philtrum',
#  '2781211006': 'Zygomatic arch',
#  '2781231350': 'Carborane',
#  '2781238917': 'Legislative intent',
#  '2781240919': 'Dyscalculia',
#  '2781243853': 'Archaism',
#  '2781244666': 'Pulmonary fibrosis',
#  '2781245245': 'Brain stem tumor',
#  '2781275174': 'Necrotizing sialometaplasia',
#  '2781304359': 'Oncidium',
#  '2781394229': 'Bond fund',
#  '2781407784': 'Pomatoschistus',
#  '2781415766': 'Intertextuality',
#  '2781417835': 'Rusty crayfish',
#  '2781421257': 'Randomized Hough transform',
#  '2781421333': 'Bushveld Igneous Complex',
#  '2781465276': 'Gillichthys',
#  '2908525026': 'Hydrochoerus hydrochaeris',
#  '2908550879': 'Glucosamine Sulfate',
#  '2908561637': 'Hairy Tongue',
#  '2908564561': 'Estrogenic Agents',
#  '2908565794': 'Neem extract',
#  '2908581292': 'Oesophageal Mucosa',
#  '2908626045': 'Urinary tract surgery',
#  '2908630131': 'Terminal Repeats',
#  '2908655827': 'Central compartment',
#  '2908659523': 'Genitourinary diseases',
#  '2908665520': 'Aminolaevulinic acid',
#  '2908687658': 'Acute edema',
#  '2908688516': 'Intercurrent disease',
#  '2908720999': 'Lysinoalanine',
#  '2908757401': 'Immune complex glomerulonephritis',
#  '2908759757': 'Selective vagotomy',
#  '2908804484': 'Fifth fingers',
#  '2908810947': 'Penicillin G Acylase',
#  '2908834855': 'Periapical tissue',
#  '2908865914': 'Patient review',
#  '2908882559': 'Facial nerve palsy',
#  '2908883125': 'Middle phalanx',
#  '2908892010': 'Circulation disorders',
#  '2908897310': 'SUBCUTANEOUS MASS',
#  '2908905237': 'Anatomical surface',
#  '2908913012': 'Bone Mineral Contents',
#  '2908914913': 'Psychiatric status rating scales',
#  '2908954029': 'Tympanuchus cupido',
#  '2908965487': 'Line Spread Function',
#  '2908969887': 'Kinase binding',
#  '2908975675': 'Butyl chloride',
#  '2908976670': 'Human Circadian Rhythms',
#  '2908979931': 'Simple sample',
#  '2909005383': 'Sham Intervention',
#  '2909073284': 'Corrosive acid',
#  '2909090905': 'Colchicine treatment',
#  '2909127641': 'Cardiac Catheterization Procedures',
#  '2909142473': 'Low folate',
#  '2909148701': 'Genetic Medicine',
#  '2909150814': 'Schisandra sphenanthera',
#  '2909154927': 'Sexual deviance',
#  '2909154947': 'Home context',
#  '2909176522': 'Methylenetetrahydrofolate reductase deficiency',
#  '2909180971': 'Haemoglobin levels',
#  '2909192745': 'External ears',
#  '2909212734': 'C-reactive protein measurement',
#  '2909222829': 'Mild persistent asthma',
#  '2909239177': 'MiRNA binding',
#  '2909254319': 'Atriplex canescens',
#  '2909257275': '5-Lipoxygenase Inhibitor',
#  '2909265136': 'Left main coronary artery disease',
#  '2909289076': 'Critical fusion frequency',
#  '2909303788': 'Hepatic stellate cell proliferation',
#  '2909305453': 'Neodymium chloride',
#  '2909331580': 'Therapist attitudes',
#  '2909332066': 'Flat Epithelial Atypia',
#  '2909339586': 'Rectal Tumors',
#  '2909351220': 'Obstetrical surgery',
#  '2909369813': 'Diameter.long',
#  '2909389164': 'Anthocyanin biosynthesis',
#  '2909408391': 'Manual insertion',
#  '2909413390': 'Artemia sp.',
#  '2909418262': 'Papillomavirus Vaccines',
#  '2909421762': 'Partial Motor Seizure',
#  '2909432230': 'Trogoderma granarium',
#  '2909436023': '2-Oxoglutarate',
#  '2909458953': 'Pollen maturation',
#  '2909525970': 'C-glycoside',
#  '2909537313': 'Molossidae',
#  '2909556672': 'Antileukemic agent',
#  '2909558360': 'Fetal heart rate monitoring',
#  '2909582518': 'Fruiting body formation',
#  '2909583644': 'Dust mites',
#  '2909587263': 'Dentin permeability',
#  '2909597292': 'Granddaughter',
#  '2909606488': 'Chromosomal anomaly',
#  '2909616942': 'Thyroid hormone transport',
#  '2909647968': 'Strategy training',
#  '2909672441': 'Suction catheters',
#  '2909679945': 'Temporary blindness',
#  '2909680518': 'Unilateral inguinal hernia',
#  '2909685455': 'Oenanthe javanica',
#  '2909690666': 'Small foot',
#  '2909699456': 'Absolute Change',
#  '2909711946': 'Mefloquina',
#  '2909725321': 'Fitting Problems',
#  '2909739737': 'Ciliary transition zone',
#  '2909766692': 'Anterior thoracic wall',
#  '2909775152': 'Radiation monitors',
#  '2909778672': 'MRSA bacteremia',
#  '2909781817': 'Steroid Compound',
#  '2909801781': 'Implant dentures',
#  '2909803459': 'CD3 Complex',
#  '2909812557': 'Inflamed joints',
#  '2909830435': 'Propiltiouracilo',
#  '2909853541': 'Aerial mycelium formation',
#  '2909864785': 'Abnormal results',
#  '2909867042': 'Arterial ischemia',
#  '2909882984': 'Helsinki declaration',
#  '2909887664': 'Dermal fibrosis',
#  '2909894122': 'Butyl Methoxydibenzoylmethane',
#  '2909898454': 'Plant Weeds',
#  '2909903242': 'Hormone sensitivity',
#  '2909928504': 'Haloalcohol',
#  '2909953522': 'Cutaneous hemangiomas',
#  '2909959062': 'Spine infection',
#  '2909979017': 'Primary Chondrosarcoma',
#  '2909984902': 'Respiratory difficulty',
#  '2909999620': 'Tooth roots',
#  '2910022395': 'Viral genetics',
#  '2910042169': 'TSH secretion',
#  '2910049597': 'Radial neck fracture',
#  '2910070171': 'Dental restorative materials',
#  '2910074453': 'Dioxygenase activity',
#  '2910081129': 'Pasteurella pestis',
#  '2910094832': 'Within Defined Limits',
#  '2910116309': 'Directive Counseling',
#  '2910131517': 'Struthioniformes',
#  '2910136436': 'Abnormal appearance',
#  '2910155306': 'Adult onset asthma',
#  '2910159872': 'Commelina diffusa',
#  '2910173840': 'Company secretary',
#  '2910184504': 'Last menstrual period',
#  '2910208683': 'Thyroid papillary carcinoma',
#  '2910214790': 'Percutaneous transhepatic cholangioscopy',
#  '2910227908': 'Variant angina pectoris',
#  '2910242117': 'Posterior capsule opacification',
#  '2910274570': 'Myeloproliferative Disorders',
#  '2910280123': 'Tablespoon',
#  '2910349948': 'Prohexadione-Ca',
#  '2910351209': 'Estrogen Receptor Status',
#  '2910351856': 'Leptomeninges',
#  '2910376568': 'Parotid tumours',
#  '2910379415': 'Urea hydrogen peroxide',
#  '2910380369': 'Syphilis serology',
#  '2910385966': 'Closed society',
#  '2910390954': 'T cell cytokine production',
#  '2910391874': 'Cellulose acetate-butyrate',
#  '2910396414': 'Cephradine',
#  '2910398257': 'Polarographic measurement',
#  '2910443920': 'Funding allocation',
#  '2910462512': 'Myrtus communis',
#  '2910490842': 'Inverse Association',
#  '2910510804': 'Theatre nurse',
#  '2910522956': 'Nitroparaffins',
#  '2910558284': 'Mass increment',
#  '2910573852': 'Respiratory samples',
#  '2910574241': 'Cocaine toxicity',
#  '2910597067': 'Nosema bombycis',
#  '2910600865': 'Surgical Specialty',
#  '2910613834': 'HEART INFARCTION',
#  '2910614246': 'Ligament Laxity',
#  '2910623234': 'Protein calcium',
#  '2910632978': 'SEC Translocation Channels',
#  '2910645160': 'Climatic Processes',
#  '2910671058': 'Smoked food',
#  '2910678341': 'Gynaecology department',
#  '2910722041': 'Interpersonal difficulties',
#  '2910730595': 'Graft Type',
#  '2910733964': 'Black iron oxide',
#  '2910751450': 'Glucocorticoid receptor binding',
#  '2910758328': 'Eurycea bislineata',
#  '2910761757': 'Anal dilatation',
#  '2910763511': 'Protein kinase C activation',
#  '2910766918': 'Mucosa disease',
#  '2910797885': 'Micropapillary carcinoma',
#  '2910814631': 'Populus simonii',
#  '2910835170': 'Tissue metabolism',
#  '2910836398': 'Plant Dispersal',
#  '2910838710': 'Item Collection',
#  '2910847617': 'Fluorocarbon Emulsions',
#  '2910849626': 'Human milk fortifier',
#  '2910883854': 'Initiation rites',
#  '2910888138': 'Primary angle-closure glaucoma',
#  '2910908761': 'Azasteroid',
#  '2910920753': 'Helicase Gene',
#  '2910940386': 'Noxious fumes',
#  '2910948145': 'Intraventricular pressure',
#  '2911021693': 'Biological profile',
#  '2911056279': 'Olive Baboons',
#  '2911060300': 'Vacuolar acidification',
#  '2911080903': 'Bacterial antibiotic resistance',
#  '2911082831': 'CNS Involvement',
#  '2911092785': 'Draught beer',
#  '2911109394': 'Antagonists & inhibitors',
#  '2911119123': 'Cumulative Exposure',
#  '2911122560': 'Nipple shield',
#  '2911124876': 'Suppurative infection',
#  '2911125813': 'Patched Receptors',
#  '2911146875': 'Cefuroxime Sodium',
#  '2911182032': 'Superior semicircular canal dehiscence syndrome',
#  '2911182894': 'Sleep dysfunction',
#  '2911207048': 'Neurological Model',
#  '2911210777': 'Addictive drugs',
#  '482391': 'Acronym',
#  '1147972': 'Goodman relation',
#  '1653862': 'Continuity tester',
#  '1667742': 'Image retrieval',
#  '2224410': 'Alidade',
#  '2952925': 'Artin–Schreier theory',
#  '3544514': 'Humid continental climate',
#  '3810323': 'Integrated assessment modelling',
#  '4957475': 'S/KEY',
#  '5970030': 'Plerocercoid',
#  '7214806': 'Mulliken population analysis',
#  '10419127': 'Cell-free system',
#  '10547277': 'Least-upper-bound property',
#  '13672336': 'Bag-of-words model',
#  '14053116': 'N-terminus',
#  '14571615': 'Directory information tree',
#  '14980834': 'Key stretching',
#  '15190523': 'Non-deterministic Turing machine',
#  '15522600': 'Cluster decay',
#  '15824746': 'Ghost cell',
#  '15852256': 'Chern–Simons theory',
#  '16277566': 'Symphony',
#  '21582691': 'Melting-point depression',
#  '22461511': 'Virtual retinal display',
#  '22738907': 'Casualty insurance',
#  '22860579': 'Ribosomal Intergenic Spacer analysis',
#  '22983694': 'Chemistry (relationship)',
#  '23528732': 'Science, technology and society',
#  '23725684': 'Maintenance engineering',
#  '24292678': 'Wittig reaction',
#  '25024680': 'Srizbi botnet',
#  '26218039': 'Helmet streamer',
#  '27549733': 'Dongba symbols',
#  '27710674': 'Dual superconductor model',
#  '28745240': 'Active laser medium',
#  '30072841': 'Diagonalizable matrix',
#  '30228295': 'Total shareholder return',
#  '32834411': 'Distinctness of image',
#  '35869016': 'Software architecture',
#  '38095332': 'Riphean',
#  '38710091': 'Frustration',
#  '38753444': 'Inverse-square law',
#  '39350307': 'Preferred reporting items for systematic reviews and meta-analyses',
#  '41661131': 'Interrupt',
#  '43138044': 'Psycho-oncology',
#  '43239065': 'Rank abundance curve',
#  '43450049': 'Psychoanalytic theory',
#  '43592290': 'Placer mining',
#  '43820063': 'Logic probe',
#  '47107517': 'Task-positive network',
#  '50479213': 'Stochastic drift',
#  '53730454': 'Atmospheric-pressure laser ionization',
#  '53840999': 'Equivalent rectangular bandwidth',
#  '55864363': 'Radiant flux',
#  '63184880': 'Hydraulic conductivity',
#  '65067816': 'Computer-assisted web interviewing',
#  '65313323': 'ANFO',
#  '67536143': 'Galois group',
#  '68015696': 'Cognitive rehabilitation therapy',
#  '68757728': 'DEVS',
#  '68782407': 'Counting points on elliptic curves',
#  '70410870': 'Clinical psychology',
#  '70688697': 'Scoring functions for docking',
#  '74175586': 'Castor wax',
#  '75082401': 'Omega equation',
#  '76965819': 'Haynes–Shockley experiment',
#  '77319485': 'Protein–ligand docking',
#  '79072407': 'Flip chip',
#  '79367842': 'Coral reef',
#  '79369538': 'Minority interpretations of quantum mechanics',
#  '79708077': 'Normal-Wishart distribution',
#  '80134875': 'Pre-Illinoian',
#  '80862487': 'Somatomedin',
#  '81286331': 'Industrialization of services business model',
#  '81439078': 'In situ hybridization',
#  '81693640': 'Bud',
#  '82201958': 'Narcissistic supply',
#  '82823613': 'Bare trust',
#  '82844589': 'Uraninite',
#  '82988372': 'H5N1 genetic structure',
#  '83200177': 'Ribosomal frameshift',
#  '83713313': 'HSPA9',
#  '83875123': 'Deviation risk measure',
#  '84418412': 'Digital forensics',
#  '85240126': 'Transvection',
#  '85323577': 'Nymph',
#  '87007009': 'Statistical hypothesis testing',
#  '88337583': 'Underactuation',
#  '88520388': 'SSH File Transfer Protocol',
#  '88629717': 'Information bias',
#  '92880739': 'Nanocomposite',
#  '92951342': 'Orthonormality',
#  '92998641': 'Schmidt sting pain index',
#  '98371066': 'Euclidean algorithm',
#  '99545648': 'Minimum-cost flow problem',
#  '105781521': 'Connell–Slatyer model of ecological succession',
#  '106165642': 'Dead reckoning',
#  '106195933': 'Truncation (statistics)',
#  '108203506': 'Reconstruction conjecture',
#  '108970007': 'Anoxic waters',
#  '109591128': 'STAT5A',
#  '110050840': 'Turbofan',
#  '111442797': 'Rand index',
#  '116402615': 'Mating system',
#  '116567970': 'Biobank',
#  '119119024': 'Category 5 cable',
#  '119432652': 'Nucleophilic abstraction',
#  '119850591': 'Aquaponics',
#  '122005561': 'Anycast',
#  '123784306': 'Vehicle routing problem',
#  '124566792': "Telegrapher's equations",
#  '126753816': 'Sedimentary depositional environment',
#  '127210992': 'Volume of fluid method',
#  '128803854': 'Eigenfunction',
#  '131140672': 'Processivity',
#  '131578233': 'Biological specificity',
#  '131955906': 'Matrix number',
#  '132915176': 'Ceiling balloon',
#  '133905733': 'Multifractal system',
#  '137357255': 'Frustration of purpose',
#  '137617129': 'Hajos–Parrish–Eder–Sauer–Wiechert reaction',
#  '137975842': 'Ion trapping',
#  '138999460': 'Solid solution',
#  '141404270': 'Trigamma function',
#  '143948831': 'Embryoid body',
#  '145151356': 'Rossby wave',
#  '145899342': 'Galois module',
#  '146172628': 'Latent semantic indexing',
#  '146980249': 'Remote visual inspection',
#  '148102462': 'Gonadal ridge',
#  '149712012': 'Riparian forest',
#  '156896111': 'Oxygen equivalent',
#  '157626507': 'Virtual routing and forwarding',
#  '158319403': 'Fractional coloring',
#  '158846371': 'Blood flow',
#  '159319019': 'Organizational chart',
#  '162269090': 'Rope',
#  '163839840': 'Choice set',
#  '165062768': 'Biomimetics',
#  '165377118': 'Scud',
#  '165790156': 'Sales order',
#  '166397571': 'Vascular tissue',
#  '167693441': 'Privacy for research participants',
#  '168006643': 'DVD-Video',
#  '168410860': 'Icicle',
#  '169708809': 'Explosive booster',
#  '171659815': 'Network interface controller',
#  '173153575': 'Inflaton',
#  '173366509': 'Reductionism',
#  '173676486': 'Character large object',
#  '174932828': 'Vigesimal',
#  '175599981': 'Parasitic castration',
#  '177800056': 'Flammability limit',
#  '177838922': 'Classical and quantum conductivity',
#  '178910020': 'Sagittal plane',
#  '179603123': 'Modeling language',
#  '180194971': 'Universal Description Discovery and Integration',
#  '180205008': 'Amplitude',
#  '180567365': 'Holland Codes',
#  '182437060': 'Cut-through switching',
#  '182461568': 'Tangible property',
#  '182621250': 'Hapticity',
#  '185245429': 'Architecture description language',
#  '186034837': 'Arthashastra',
#  '186941935': 'Algebra over a field',
#  '187120659': 'Countercurrent exchange',
#  '187212893': 'Pediatrics',
#  '189719970': 'Self-information',
#  '191952053': 'Dopant',
#  '192144319': 'DEFLATE',
#  '194305327': 'Manual fire alarm activation',
#  '195915863': 'k·p perturbation theory',
#  '202733679': 'Meroplankton',
#  '205570205': 'Measurement microphone calibration',
#  '205875254': 'Decentralised system',
#  '532726627': 'Western culture',
#  '541865764': 'Chinese poetry',
#  '546175201': 'Buddhist studies',
#  '2775857624': 'Subfornical organ',
#  '2775872946': 'Hair conditioner',
#  '2775907739': 'Determinative',
#  '2775935354': 'Rhus chinensis',
#  '2775954050': 'Sedation dentistry',
#  '2775970465': 'Epicanthoplasty',
#  '2775984225': 'Pinacidil',
#  '2776014378': 'Core Knowledge',
#  '2776019183': 'Maritimes Basin',
#  '2776096353': 'Shear strength test',
#  '2776172968': 'Tropical climate',
#  '2776177110': 'Internal granular layer',
#  '2776193875': 'Linearizer',
#  '2776225092': 'Autoethnography',
#  '2776326425': 'Pancreatic elastase',
#  '2776446032': 'Iridomyrmex',
#  '2776448016': 'Hydropneumatic suspension',
#  '2776550021': 'RIPK1',
#  '2776569323': 'Bacillus isolates',
#  '2776600044': 'Kaizen',
#  '2776624037': 'Evaporating dish',
#  '2776639550': 'Armenian',
#  '2776645389': 'Genetypes',
#  '2776663829': 'Interference filter',
#  '2776703650': 'Hemiculter',
#  '2776739417': 'Vesicomyidae',
#  '2776769153': 'Luminance meter',
#  '2776820912': 'Lithium peroxide',
#  '2776875392': 'Hemiazygos vein',
#  '2776889141': 'Eriogonum',
#  '2776907638': 'Lixisol',
#  '2776920293': 'APLP1',
#  '2776924250': 'Circulene',
#  '2776927880': 'Embryo rescue',
#  '2776940356': 'Rasmussen syndrome',
#  '2776944092': 'Acicular ferrite',
#  '2776960383': 'Line fitting',
#  '2776965311': 'Camel milk',
#  '2776978656': 'Family romance',
#  '2776993930': 'Stereology',
#  '2777023891': 'Suffix tree clustering',
#  '2777124089': 'Holcus lanatus',
#  '2777153008': 'Lithium hydride',
#  '2777155046': 'Helenium',
#  '2777203310': 'Transfer pricing',
#  '2777203906': 'Dodecyl gallate',
#  '2777282899': 'Tendency of the rate of profit to fall',
#  '2777322871': 'Creative education',
#  '2777323237': 'Arabic script',
#  '2777352164': 'Trimellitic acid',
#  '2777423100': 'Breast ultrasound',
#  '2777445357': 'Bufotenin',
#  '2777457135': 'Metallophyte',
#  '2777466363': 'Design tool',
#  '2777467267': "1,1'-Bi-2-naphthol",
#  '2777499946': 'High Bandwidth Memory',
#  '2777540144': 'Tidal circularization',
#  '2777563384': 'Ideal chain',
#  '2777578932': 'Histiocytic sarcoma',
#  '2777626736': 'Nudibranch',
#  '2777642724': 'Salvelinus leucomaenis',
#  '2777651691': 'NLRP7',
#  '2777666592': 'On Demand Routing',
#  '2777686142': 'Radiologic sign',
#  '2777698166': 'Gentianales',
#  '2777706067': 'Isolation by distance',
#  '2777707825': 'Chronic cough',
#  '2777718703': 'Machine control',
#  '2777795908': 'Solidago virgaurea',
#  '2777796192': 'Exclosure',
#  '2777831649': 'Solasonine',
#  '2777835334': 'Tympanocentesis',
#  '2777887363': 'Harmonia',
#  '2777895073': "Plant breeders' rights",
#  '2777917747': 'Pancreatic mass',
#  '2777926767': 'Drug-related crime',
#  '2777936497': 'Light switch',
#  '2777965283': 'Digit symbol substitution test',
#  '2777966105': 'Arabinose isomerase',
#  '2778031743': 'Latticework',
#  '2778081122': 'Rosacea',
#  '2778083150': 'Mesocrystal',
#  '2778097640': 'Particle damping',
#  '2778143190': 'Minnesota Geological Survey',
#  '2778159086': 'Copenhagen criteria',
#  '2778178086': 'Chlorin',
#  '2778182776': 'Melatonin',
#  '2778198833': 'Erythrokeratodermia variabilis',
#  '2778206073': 'IEEE 802.11p',
#  '2778215999': 'Nevus comedonicus',
#  '2778304562': 'Pollution in China',
#  '2778311535': 'Agabus',
#  '2778357562': 'Cytisus scoparius',
#  '2778370464': 'Student activities',
#  '2778373014': 'Serration',
#  '2778400599': 'Paternò–Büchi reaction',
#  '2778406374': 'Tuberculoma',
#  '2778424037': 'Crabronidae',
#  '2778443876': 'Amnesic shellfish poisoning',
#  '2778481086': 'Marketing board',
#  '2778492874': 'Tree nut allergy',
#  '2778507531': '4-Phenylpiperidine',
#  '2778509835': 'Rational addiction',
#  '2778600920': 'Airport surveillance radar',
#  '2778636764': 'Red Globe',
#  '2778655484': 'Reticular formation',
#  '2778670359': 'DiOC6',
#  '2778670631': 'Ametropic amblyopia',
#  '2778758164': 'Onycholysis',
#  '2778780700': 'Intrauterine growth restriction',
#  '2778816116': 'Arbekacin',
#  '2778817777': 'Track lighting',
#  '2778827957': 'Diamond tool',
#  '2778832859': 'Alloy wheel',
#  '2778837545': 'Core Labor Standards',
#  '2778863065': 'Autosomal recessive cerebellar ataxia',
#  '2778882308': 'Feminization of poverty',
#  '2778906322': 'Tetrahydromethanopterin',
#  '2778921735': 'Intelligent electronic device',
#  '2778960357': 'Rift Valley fever',
#  '2779011268': 'Aortic valve repair',
#  '2779043514': 'Vulgarism',
#  '2779044513': 'Hyperthyroxinemia',
#  '2779054714': 'Water–cement ratio',
#  '2779057573': 'Fallopian tube obstruction',
#  '2779078216': 'Tuberculosis vaccines',
#  '2779085140': 'Tremellales',
#  '2779110813': 'Macrocystis pyrifera',
#  '2779120801': 'Polypeptide N-acetylgalactosaminyltransferase',
#  '2779123355': 'Copolyester',
#  '2779146052': 'Arthropathy',
#  '2779161064': 'Silodosin',
#  '2779165828': 'Procedural sedation and analgesia',
#  '2779184092': 'Carriageway',
#  '2779211877': 'Redox indicator',
#  '2779274276': 'Pseudodiploid',
#  '2779277616': 'Podostemaceae',
#  '2779285336': 'Lacunar stroke',
#  '2779298689': 'Deadly force',
#  '2779311582': 'SIDD',
#  '2779314219': 'Longspur',
#  '2779319286': 'Riluzole',
#  '2779367895': 'Minim',
#  '2779370837': 'Thymopoietin',
#  '2779390272': 'Reed–Sternberg cell',
#  '2779398323': 'Dalbergia latifolia',
#  '2779417040': 'Frangula alnus',
#  '2779462423': 'Common good (economics)',
#  '2779478434': 'Cohenite',
#  '2779537295': 'Lifestyle medicine',
#  '2779545503': 'Resonance-enhanced multiphoton ionization',
#  '2779545769': 'Closeness',
#  '2779552090': 'Ecallantide',
#  '2779643914': 'Primary sensory areas',
#  '2779705797': 'Angiolymphoid hyperplasia with eosinophilia',
#  '2779715144': 'Bicycle lighting',
#  '2779732015': "Banti's syndrome",
#  '2779733813': 'Cloud gaming',
#  '2779767251': 'Marxist feminism',
#  '2779771984': 'Cortical granule',
#  '2779808145': 'Reference card',
#  '2779814830': 'Energy Policy Act of 1992',
#  '2779815552': 'Proline',
#  '2779850944': 'Titi',
#  '2779892413': 'Pneumococcal pneumonia',
#  '2779910497': 'Parasympathetic ganglion',
#  '2779920057': 'Coordinate-free',
#  '2779928471': 'Level playing field',
#  '2779933583': 'Phoenicopteridae',
#  '2779968005': 'Masked depression',
#  '2780008190': 'DEET',
#  '2780013280': 'Quintal',
#  '2780014084': 'Debt restructuring',
#  '2780016533': 'Tropical instability waves',
#  '2780023243': 'Phosphoenolpyruvic acid',
#  '2780037603': 'Scopula',
#  '2780045279': 'Overlapping consensus',
#  '2780068616': 'Rheophyte',
#  '2780090675': 'Mitochondrial ribosome',
#  '2780098337': 'Merluccius gayi',
#  '2780157541': 'Hyacinth',
#  '2780251316': 'Sialoadhesin',
#  '2780266093': 'Illex coindetii',
#  '2780295629': 'Santolina',
#  '2780342470': 'Mythimna unipuncta',
#  '2780355955': 'Mesoamerican nephropathy',
#  '2780361610': 'Mevalonic acid',
#  '2780364759': 'Mosquito coil',
#  '2780378901': 'Sporormiella',
#  '2780397019': 'Protonophore',
#  '2780422782': 'Acrolein',
#  '2780451842': 'Nickel hydride',
#  '2780466727': 'Squirmer',
#  '2780509222': 'Compact Muon Solenoid',
#  '2780510799': 'Sporolactobacillus',
#  '2780517854': 'Ceratomyxa shasta',
#  '2780534625': 'Canine herpesvirus',
#  '2780578770': 'Gliomatosis cerebri',
#  '2780582031': 'Color scheme',
#  '2780586966': 'Tax expenditure',
#  '2780588981': 'Eltrombopag',
#  '2780602078': 'KLK7',
#  '2780705134': '2,3-sigmatropic rearrangement',
#  '2780714801': 'Crime displacement',
#  '2780723184': 'Megestrol acetate',
#  '2780785531': 'Dromiidae',
#  '2780876601': 'Rhabditida',
#  '2780926990': 'Sparfloxacin',
#  '2780952055': 'Axonopus compressus',
#  '2780967403': 'Bilateral trade',
#  '2781064192': 'gamma-Tocopherol',
#  '2781068240': 'Diastematomyelia',
#  '2781078495': 'Helix lucorum',
#  '2781106498': 'Intransitive verb',
#  '2781174663': 'Sphingobacteria',
#  '2781184437': 'Prochilodus magdalenae',
#  '2781189437': 'Oil pressure',
#  '2781201906': 'Capoeta trutta',
#  '2781205627': 'Available water capacity',
#  ...}

# %%
fos_index2
# Out:
# {'10000559': 0,
#  '100012643': 1,
#  '100017401': 2,
#  '100020394': 3,
#  '100022809': 4,
#  '100028377': 5,
#  '100036529': 6,
#  '100044566': 7,
#  '100044655': 8,
#  '10005042': 9,
#  '10005230': 10,
#  '100053769': 11,
#  '100065037': 12,
#  '100068826': 13,
#  '100082104': 14,
#  '100083437': 15,
#  '100086909': 16,
#  '100087112': 17,
#  '100094221': 18,
#  '100094513': 19,
#  '100100210': 20,
#  '100102862': 21,
#  '10010492': 22,
#  '100106864': 23,
#  '100107663': 24,
#  '100129307': 25,
#  '100134115': 26,
#  '100136789': 27,
#  '100139498': 28,
#  '100142294': 29,
#  '100143864': 30,
#  '100148910': 31,
#  '100149206': 32,
#  '100155856': 33,
#  '100157288': 34,
#  '100158260': 35,
#  '100175707': 36,
#  '100175905': 37,
#  '100185428': 38,
#  '100187453': 39,
#  '100188561': 40,
#  '10020367': 41,
#  '100203831': 42,
#  '100206155': 43,
#  '100206748': 44,
#  '100207259': 45,
#  '100207952': 46,
#  '10021369': 47,
#  '10021790': 48,
#  '100220312': 49,
#  '100220837': 50,
#  '100229915': 51,
#  '100234860': 52,
#  '100243477': 53,
#  '100245971': 54,
#  '100253034': 55,
#  '100259107': 56,
#  '100260852': 57,
#  '100270623': 58,
#  '100276221': 59,
#  '100279318': 60,
#  '100279451': 61,
#  '100293340': 62,
#  '100297711': 63,
#  '100298382': 64,
#  '100299639': 65,
#  '100302947': 66,
#  '100302975': 67,
#  '100307554': 68,
#  '100329506': 69,
#  '100335711': 70,
#  '100339178': 71,
#  '100342000': 72,
#  '100342038': 73,
#  '100359661': 74,
#  '100363876': 75,
#  '100368936': 76,
#  '100374796': 77,
#  '100376341': 78,
#  '10037775': 79,
#  '10038465': 80,
#  '100396543': 81,
#  '100398564': 82,
#  '100402318': 83,
#  '100405246': 84,
#  '100406419': 85,
#  '100409575': 86,
#  '100410459': 87,
#  '100412989': 88,
#  '100413370': 89,
#  '100425013': 90,
#  '100433359': 91,
#  '100454173': 92,
#  '100460472': 93,
#  '100461760': 94,
#  '100463513': 95,
#  '100468782': 96,
#  '100474770': 97,
#  '100478631': 98,
#  '100479058': 99,
#  '100480397': 100,
#  '100481476': 101,
#  '100485629': 102,
#  '100486739': 103,
#  '100494639': 104,
#  '100500283': 105,
#  '10050518': 106,
#  '100505606': 107,
#  '100512324': 108,
#  '100515483': 109,
#  '100516043': 110,
#  '100521375': 111,
#  '100533687': 112,
#  '100536367': 113,
#  '100537666': 114,
#  '100544194': 115,
#  '100546448': 116,
#  '100548800': 117,
#  '10055345': 118,
#  '10055564': 119,
#  '100560664': 120,
#  '100563656': 121,
#  '100564792': 122,
#  '100575273': 123,
#  '100587491': 124,
#  '10058791': 125,
#  '100594029': 126,
#  '100595998': 127,
#  '100598020': 128,
#  '100600661': 129,
#  '100602654': 130,
#  '10060692': 131,
#  '100607858': 132,
#  '100609095': 133,
#  '10061420': 134,
#  '100631289': 135,
#  '100633990': 136,
#  '100635051': 137,
#  '100643331': 138,
#  '10064560': 139,
#  '100648641': 140,
#  '100660578': 141,
#  '100666072': 142,
#  '100673868': 143,
#  '100675267': 144,
#  '100684664': 145,
#  '100687433': 146,
#  '100691959': 147,
#  '100694443': 148,
#  '100695618': 149,
#  '100701293': 150,
#  '100701532': 151,
#  '100705429': 152,
#  '100706131': 153,
#  '100709050': 154,
#  '100709749': 155,
#  '100709819': 156,
#  '100716732': 157,
#  '100722585': 158,
#  '100723438': 159,
#  '100725284': 160,
#  '100726288': 161,
#  '1007266': 162,
#  '100729193': 163,
#  '100733574': 164,
#  '100735349': 165,
#  '100752510': 166,
#  '100752768': 167,
#  '100762109': 168,
#  '100763855': 169,
#  '100767440': 170,
#  '100773728': 171,
#  '1007738': 172,
#  '100773827': 173,
#  '100776233': 174,
#  '100780047': 175,
#  '100784341': 176,
#  '100787162': 177,
#  '100791953': 178,
#  '100793964': 179,
#  '10079403': 180,
#  '100796255': 181,
#  '100796937': 182,
#  '100797621': 183,
#  '100798922': 184,
#  '100799343': 185,
#  '100800780': 186,
#  '100805817': 187,
#  '100806243': 188,
#  '10080731': 189,
#  '100808899': 190,
#  '100815425': 191,
#  '100817775': 192,
#  '100834320': 193,
#  '100836998': 194,
#  '100837961': 195,
#  '1008401': 196,
#  '100843635': 197,
#  '100850083': 198,
#  '10085336': 199,
#  '100853524': 200,
#  '100856211': 201,
#  '100858432': 202,
#  '100859065': 203,
#  '100859804': 204,
#  '100872483': 205,
#  '100873260': 206,
#  '100882016': 207,
#  '100888174': 208,
#  '100889939': 209,
#  '100893083': 210,
#  '100898757': 211,
#  '100899422': 212,
#  '100900200': 213,
#  '10090317': 214,
#  '100903775': 215,
#  '100905312': 216,
#  '100906024': 217,
#  '100906831': 218,
#  '100918236': 219,
#  '100919365': 220,
#  '100921725': 221,
#  '100924687': 222,
#  '100925783': 223,
#  '100932681': 224,
#  '100933400': 225,
#  '100942924': 226,
#  '100944820': 227,
#  '100949728': 228,
#  '100951216': 229,
#  '100963093': 230,
#  '100970517': 231,
#  '1009742': 232,
#  '1009745': 233,
#  '100980136': 234,
#  '100988078': 235,
#  '100991257': 236,
#  '100991261': 237,
#  '100991340': 238,
#  '100991488': 239,
#  '1009929': 240,
#  '101000010': 241,
#  '101014631': 242,
#  '101021046': 243,
#  '101026917': 244,
#  '101027131': 245,
#  '101044782': 246,
#  '101049965': 247,
#  '101050124': 248,
#  '101053622': 249,
#  '101054994': 250,
#  '101056560': 251,
#  '101066485': 252,
#  '101068787': 253,
#  '101068798': 254,
#  '101070640': 255,
#  '101075120': 256,
#  '101077360': 257,
#  '101077781': 258,
#  '101082671': 259,
#  '101083039': 260,
#  '101092202': 261,
#  '101094217': 262,
#  '101094754': 263,
#  '101097943': 264,
#  '101104100': 265,
#  '101112237': 266,
#  '101126769': 267,
#  '101139013': 268,
#  '101140149': 269,
#  '101142422': 270,
#  '101142426': 271,
#  '101152365': 272,
#  '101154568': 273,
#  '101156304': 274,
#  '101161028': 275,
#  '10116572': 276,
#  '101173714': 277,
#  '101175848': 278,
#  '101180180': 279,
#  '101181784': 280,
#  '101185895': 281,
#  '10118631': 282,
#  '101188967': 283,
#  '101195511': 284,
#  '101195712': 285,
#  '101199243': 286,
#  '101204015': 287,
#  '101208852': 288,
#  '101216236': 289,
#  '101219045': 290,
#  '101225424': 291,
#  '101225446': 292,
#  '101230327': 293,
#  '101240365': 294,
#  '1012414': 295,
#  '101246355': 296,
#  '101248139': 297,
#  '101252448': 298,
#  '101252705': 299,
#  '101257415': 300,
#  '101265243': 301,
#  '101266164': 302,
#  '101267510': 303,
#  '101268889': 304,
#  '101271287': 305,
#  '101273638': 306,
#  '101276457': 307,
#  '10128374': 308,
#  '101293273': 309,
#  '101300250': 310,
#  '101302269': 311,
#  '101303905': 312,
#  '101313458': 313,
#  '101316353': 314,
#  '101317890': 315,
#  '101322438': 316,
#  '101335993': 317,
#  '101336063': 318,
#  '101336846': 319,
#  '101346110': 320,
#  '10134942': 321,
#  '101351245': 322,
#  '101354216': 323,
#  '101360934': 324,
#  '101370240': 325,
#  '101382669': 326,
#  '10138342': 327,
#  '101386981': 328,
#  '101396194': 329,
#  '101396714': 330,
#  '101403955': 331,
#  '101404756': 332,
#  '101410826': 333,
#  '101411860': 334,
#  '101414908': 335,
#  '101425835': 336,
#  '101426380': 337,
#  '101433766': 338,
#  '101434241': 339,
#  '101440886': 340,
#  '10144332': 341,
#  '10144844': 342,
#  '101452262': 343,
#  '10145245': 344,
#  '101453961': 345,
#  '101454708': 346,
#  '10145767': 347,
#  '101457746': 348,
#  '10146269': 349,
#  '101468663': 350,
#  '10147152': 351,
#  '101471828': 352,
#  '101472132': 353,
#  '101472996': 354,
#  '101474431': 355,
#  '101476363': 356,
#  '101479696': 357,
#  '101480719': 358,
#  '101486319': 359,
#  '101487385': 360,
#  '101493165': 361,
#  '1014953': 362,
#  '101496351': 363,
#  '10150695': 364,
#  '101509794': 365,
#  '101512455': 366,
#  '101516089': 367,
#  '101518730': 368,
#  '101519877': 369,
#  '10152477': 370,
#  '101525915': 371,
#  '101531171': 372,
#  '101531613': 373,
#  '101541887': 374,
#  '101544691': 375,
#  '101544941': 376,
#  '101546441': 377,
#  '101550589': 378,
#  '101555633': 379,
#  '101561427': 380,
#  '101571972': 381,
#  '101572246': 382,
#  '101575980': 383,
#  '101577382': 384,
#  '101583263': 385,
#  '101586328': 386,
#  '101595628': 387,
#  '10159599': 388,
#  '101597101': 389,
#  '101601086': 390,
#  '101612795': 391,
#  '101612960': 392,
#  '101615488': 393,
#  '101615574': 394,
#  '101618186': 395,
#  '10161872': 396,
#  '10162356': 397,
#  '101630550': 398,
#  '101635128': 399,
#  '101638190': 400,
#  '101643646': 401,
#  '101645829': 402,
#  '10164756': 403,
#  '101649071': 404,
#  '101649592': 405,
#  '10165471': 406,
#  '101660505': 407,
#  '101666144': 408,
#  '101676477': 409,
#  '101677414': 410,
#  '101678225': 411,
#  '101680959': 412,
#  '101682238': 413,
#  '101682728': 414,
#  '101683677': 415,
#  '101691996': 416,
#  '101692577': 417,
#  '101698701': 418,
#  '101700870': 419,
#  '101710237': 420,
#  '101721835': 421,
#  '101722063': 422,
#  '101722098': 423,
#  '101737016': 424,
#  '101738243': 425,
#  '101744339': 426,
#  '101747707': 427,
#  '101749295': 428,
#  '101754097': 429,
#  '101755528': 430,
#  '101762097': 431,
#  '101765175': 432,
#  '101775428': 433,
#  '101780184': 434,
#  '101783463': 435,
#  '101796028': 436,
#  '10180917': 437,
#  '101810790': 438,
#  '101812284': 439,
#  '101814296': 440,
#  '101815171': 441,
#  '101819353': 442,
#  '101819947': 443,
#  '101826366': 444,
#  '101829350': 445,
#  '101833716': 446,
#  '101837359': 447,
#  '101842124': 448,
#  '10184394': 449,
#  '101846000': 450,
#  '101848323': 451,
#  '101850914': 452,
#  '101862033': 453,
#  '101862200': 454,
#  '101863955': 455,
#  '101864126': 456,
#  '10187374': 457,
#  '101874905': 458,
#  '101877181': 459,
#  '10187730': 460,
#  '101879516': 461,
#  '101892634': 462,
#  '101901036': 463,
#  '101908085': 464,
#  '101913822': 465,
#  '101928632': 466,
#  '101937913': 467,
#  '101943168': 468,
#  '101946123': 469,
#  '10194927': 470,
#  '101952150': 471,
#  '101957632': 472,
#  '101959639': 473,
#  '101972281': 474,
#  '101973423': 475,
#  '101980400': 476,
#  '101985253': 477,
#  '101990758': 478,
#  '101991246': 479,
#  '101997407': 480,
#  '102003337': 481,
#  '102005072': 482,
#  '102013352': 483,
#  '102013462': 484,
#  '102017705': 485,
#  '102017789': 486,
#  '102019270': 487,
#  '102029660': 488,
#  '102037460': 489,
#  '102040560': 490,
#  '102044542': 491,
#  '102044607': 492,
#  '102051916': 493,
#  '102052665': 494,
#  '102054029': 495,
#  '10205521': 496,
#  '102056067': 497,
#  '102057582': 498,
#  '102063265': 499,
#  '102063271': 500,
#  '102065156': 501,
#  '102067918': 502,
#  '102072564': 503,
#  '102073756': 504,
#  '102079904': 505,
#  '102091540': 506,
#  '102094743': 507,
#  '102107297': 508,
#  '102113618': 509,
#  '102124568': 510,
#  '102125574': 511,
#  '102130693': 512,
#  '102130813': 513,
#  '102132729': 514,
#  '102135495': 515,
#  '10213722': 516,
#  '102139631': 517,
#  '102142041': 518,
#  '102142479': 519,
#  '102144036': 520,
#  '102161783': 521,
#  '102164700': 522,
#  '102168758': 523,
#  '102170343': 524,
#  '102177615': 525,
#  '102180281': 526,
#  '102190203': 527,
#  '102192266': 528,
#  '102194203': 529,
#  '102198088': 530,
#  '102205669': 531,
#  '102213258': 532,
#  '102217409': 533,
#  '102219930': 534,
#  '102224218': 535,
#  '102225024': 536,
#  '102230213': 537,
#  '1022313': 538,
#  '102231394': 539,
#  '102232406': 540,
#  '102234262': 541,
#  '102235558': 542,
#  '102242181': 543,
#  '102248274': 544,
#  '10225806': 545,
#  '102259522': 546,
#  '102260082': 547,
#  '102264631': 548,
#  '102265111': 549,
#  '102267420': 550,
#  '102268210': 551,
#  '102280478': 552,
#  '102284421': 553,
#  '102287145': 554,
#  '102289811': 555,
#  '102290492': 556,
#  '102293001': 557,
#  '102298314': 558,
#  '102299578': 559,
#  '10229987': 560,
#  '102301625': 561,
#  '102305021': 562,
#  '102305610': 563,
#  '102306862': 564,
#  '102306995': 565,
#  '102309569': 566,
#  '102309675': 567,
#  '102313274': 568,
#  '102314930': 569,
#  '102315432': 570,
#  '102315692': 571,
#  '102333194': 572,
#  '102336505': 573,
#  '10233890': 574,
#  '10233921': 575,
#  '102349902': 576,
#  '102350818': 577,
#  '102352515': 578,
#  '102353371': 579,
#  '102359118': 580,
#  '102362939': 581,
#  '102366305': 582,
#  '102370290': 583,
#  '102375830': 584,
#  '102379954': 585,
#  '102379996': 586,
#  '102380595': 587,
#  '10238366': 588,
#  '102387403': 589,
#  '102392041': 590,
#  '102398437': 591,
#  '102404424': 592,
#  '102408133': 593,
#  '102414288': 594,
#  '102439081': 595,
#  '102450924': 596,
#  '102451475': 597,
#  '10245270': 598,
#  '102456905': 599,
#  '102458011': 600,
#  '102459505': 601,
#  '102462485': 602,
#  '102478456': 603,
#  '102483320': 604,
#  '102483414': 605,
#  '10248492': 606,
#  '102486512': 607,
#  '102487863': 608,
#  '102490557': 609,
#  '102497350': 610,
#  '102498820': 611,
#  '102500504': 612,
#  '102501036': 613,
#  '102504731': 614,
#  '102513296': 615,
#  '102519508': 616,
#  '102523778': 617,
#  '102529408': 618,
#  '102536734': 619,
#  '102540577': 620,
#  '102560166': 621,
#  '102561126': 622,
#  '102565606': 623,
#  '102565666': 624,
#  '102568066': 625,
#  '102568950': 626,
#  '102570303': 627,
#  '102570824': 628,
#  '102579867': 629,
#  '102587632': 630,
#  '102587638': 631,
#  '102591085': 632,
#  '102592046': 633,
#  '102595726': 634,
#  '102595763': 635,
#  '102599761': 636,
#  '102600418': 637,
#  '102602991': 638,
#  '102607178': 639,
#  '102622118': 640,
#  '102626609': 641,
#  '102629751': 642,
#  '102634674': 643,
#  '102637530': 644,
#  '102640327': 645,
#  '102649902': 646,
#  '102650399': 647,
#  '102650607': 648,
#  '102650682': 649,
#  '102652120': 650,
#  '102655426': 651,
#  '102658986': 652,
#  '102665078': 653,
#  '102666661': 654,
#  '102670114': 655,
#  '102687321': 656,
#  '102690226': 657,
#  '1026927': 658,
#  '102701049': 659,
#  '102703901': 660,
#  '102712870': 661,
#  '102715595': 662,
#  '102720910': 663,
#  '102723702': 664,
#  '102725377': 665,
#  '102726548': 666,
#  '102727969': 667,
#  '10272871': 668,
#  '10273701': 669,
#  '102744134': 670,
#  '102747710': 671,
#  '102755159': 672,
#  '102757985': 673,
#  '102758585': 674,
#  '10277891': 675,
#  '102780508': 676,
#  '102789151': 677,
#  '102790218': 678,
#  '102792161': 679,
#  '102792778': 680,
#  '102793881': 681,
#  '102803821': 682,
#  '102805184': 683,
#  '102807365': 684,
#  '10280817': 685,
#  '102816655': 686,
#  '10281669': 687,
#  '10282146': 688,
#  '102830678': 689,
#  '102849442': 690,
#  '102855152': 691,
#  '102871797': 692,
#  '102874275': 693,
#  '102877821': 694,
#  '102879941': 695,
#  '10288518': 696,
#  '102893441': 697,
#  '102894143': 698,
#  '102900547': 699,
#  '102906071': 700,
#  '102912713': 701,
#  '102928384': 702,
#  '102931765': 703,
#  '102938260': 704,
#  '102940268': 705,
#  '102942909': 706,
#  '102943987': 707,
#  '102944935': 708,
#  '102950494': 709,
#  '102951782': 710,
#  '102959455': 711,
#  '102964294': 712,
#  '102966492': 713,
#  '102974449': 714,
#  '102988692': 715,
#  '102993220': 716,
#  '102998134': 717,
#  '102999125': 718,
#  '103000020': 719,
#  '103000137': 720,
#  '103008708': 721,
#  '103017160': 722,
#  '103020413': 723,
#  '103022837': 724,
#  '103025427': 725,
#  '103037022': 726,
#  '103038307': 727,
#  '103038586': 728,
#  '103041312': 729,
#  '103048170': 730,
#  '103048892': 731,
#  '103050880': 732,
#  '103057088': 733,
#  '103057564': 734,
#  '103060056': 735,
#  '103060772': 736,
#  '103060789': 737,
#  '103072069': 738,
#  '103073706': 739,
#  '103073914': 740,
#  '103077935': 741,
#  '103088060': 742,
#  '103093179': 743,
#  '103093684': 744,
#  '103106408': 745,
#  '103113521': 746,
#  '103132145': 747,
#  '103133801': 748,
#  '103138315': 749,
#  '103140732': 750,
#  '103144560': 751,
#  '10314817': 752,
#  '103151440': 753,
#  '103159348': 754,
#  '10316603': 755,
#  '103176879': 756,
#  '103178915': 757,
#  '103185065': 758,
#  '103189561': 759,
#  '103191249': 760,
#  '103193775': 761,
#  '103197507': 762,
#  '103200210': 763,
#  '103203806': 764,
#  '103206924': 765,
#  '103208741': 766,
#  '103215972': 767,
#  '103216963': 768,
#  '103219427': 769,
#  '103230337': 770,
#  '103232671': 771,
#  '103234275': 772,
#  '103235431': 773,
#  '103244968': 774,
#  '103247709': 775,
#  '10324989': 776,
#  '10325510': 777,
#  '103256973': 778,
#  '10325715': 779,
#  '103257674': 780,
#  '103262434': 781,
#  '103266176': 782,
#  '103268943': 783,
#  '103272658': 784,
#  '103272735': 785,
#  '103272765': 786,
#  '103275481': 787,
#  '103278499': 788,
#  '103284512': 789,
#  '103298420': 790,
#  '103299284': 791,
#  '103302344': 792,
#  '103302479': 793,
#  '103303479': 794,
#  '103303742': 795,
#  '103316784': 796,
#  '103317067': 797,
#  '103319777': 798,
#  '103324678': 799,
#  '1033296': 800,
#  '103339696': 801,
#  '10335311': 802,
#  '103357873': 803,
#  '103359713': 804,
#  '103364767': 805,
#  '103365431': 806,
#  '103368685': 807,
#  '103377522': 808,
#  '103378370': 809,
#  '103382277': 810,
#  '103386923': 811,
#  '103389226': 812,
#  '103390534': 813,
#  '103395026': 814,
#  '103402496': 815,
#  '103408237': 816,
#  '103423394': 817,
#  '103423482': 818,
#  '10343214': 819,
#  '103432212': 820,
#  '103432861': 821,
#  '103435993': 822,
#  '103437262': 823,
#  '1034443': 824,
#  '103452841': 825,
#  '103463560': 826,
#  '10347200': 827,
#  '103474210': 828,
#  '103474955': 829,
#  '103474985': 830,
#  '103481479': 831,
#  '103486182': 832,
#  '103488450': 833,
#  '10349047': 834,
#  '10349863': 835,
#  '103500101': 836,
#  '103504046': 837,
#  '103511597': 838,
#  '103512785': 839,
#  '103516714': 840,
#  '103520596': 841,
#  '103522932': 842,
#  '103533665': 843,
#  '103539492': 844,
#  '103545067': 845,
#  '103548071': 846,
#  '103549609': 847,
#  '103557529': 848,
#  '103565092': 849,
#  '103566474': 850,
#  '103572491': 851,
#  '10357551': 852,
#  '10357712': 853,
#  '103578098': 854,
#  '103578843': 855,
#  '103593891': 856,
#  '103607123': 857,
#  '103613024': 858,
#  '103620143': 859,
#  '103621254': 860,
#  '103623929': 861,
#  '103631654': 862,
#  '103631927': 863,
#  '103637391': 864,
#  '103642545': 865,
#  '103645729': 866,
#  '103646786': 867,
#  '103648661': 868,
#  '103652617': 869,
#  '103659442': 870,
#  '103678177': 871,
#  '103683099': 872,
#  '103684282': 873,
#  '103687842': 874,
#  '103689191': 875,
#  '103692084': 876,
#  '103692563': 877,
#  '103697071': 878,
#  '103697762': 879,
#  '103706887': 880,
#  '103708830': 881,
#  '103709681': 882,
#  '103711010': 883,
#  '103716073': 884,
#  '103725303': 885,
#  '103726522': 886,
#  '103728769': 887,
#  '103734657': 888,
#  '103738662': 889,
#  '103742611': 890,
#  '103742991': 891,
#  '103746643': 892,
#  '103749203': 893,
#  '103751382': 894,
#  '103753734': 895,
#  '103755468': 896,
#  '103756818': 897,
#  '103760667': 898,
#  '103761620': 899,
#  '103762249': 900,
#  '103764139': 901,
#  '103766332': 902,
#  '103767974': 903,
#  '103770926': 904,
#  '103778262': 905,
#  '103781064': 906,
#  '103783831': 907,
#  '103784038': 908,
#  '103785112': 909,
#  '103790658': 910,
#  '103796816': 911,
#  '103797069': 912,
#  '103813035': 913,
#  '103824480': 914,
#  '103827415': 915,
#  '103829212': 916,
#  '103830897': 917,
#  '103835126': 918,
#  '103838597': 919,
#  '10384849': 920,
#  '103853396': 921,
#  '103853494': 922,
#  '103862110': 923,
#  '103862347': 924,
#  '103862915': 925,
#  '103864889': 926,
#  '103867464': 927,
#  '103874350': 928,
#  '103878061': 929,
#  '103879163': 930,
#  '103883747': 931,
#  '103888782': 932,
#  '103888896': 933,
#  '103890833': 934,
#  '10389098': 935,
#  '103896604': 936,
#  '10389963': 937,
#  '10390562': 938,
#  '10390740': 939,
#  '103910844': 940,
#  '103913367': 941,
#  '103931877': 942,
#  '10393806': 943,
#  '103945485': 944,
#  '103962170': 945,
#  '103962331': 946,
#  '1039755': 947,
#  '103982235': 948,
#  '103987645': 949,
#  '103995592': 950,
#  '103996166': 951,
#  '104002121': 952,
#  '104011308': 953,
#  '104015590': 954,
#  '104020303': 955,
#  '104023053': 956,
#  '104031475': 957,
#  '104037064': 958,
#  '104047586': 959,
#  '104054115': 960,
#  '104055093': 961,
#  '104060986': 962,
#  '104062141': 963,
#  '104065381': 964,
#  '10406634': 965,
#  '104067677': 966,
#  '104074863': 967,
#  '104075073': 968,
#  '104075261': 969,
#  '1040795': 970,
#  '104091681': 971,
#  '104096267': 972,
#  '104108587': 973,
#  '104110773': 974,
#  '104111718': 975,
#  '10411345': 976,
#  '104114177': 977,
#  '104117666': 978,
#  '104119616': 979,
#  '104122410': 980,
#  '104129893': 981,
#  '104131967': 982,
#  '10413777': 983,
#  '104138954': 984,
#  '104140500': 985,
#  '104143935': 986,
#  '104148171': 987,
#  '104151175': 988,
#  '104169306': 989,
#  '104170005': 990,
#  '104172830': 991,
#  '104177226': 992,
#  '104177525': 993,
#  '104182661': 994,
#  '10418432': 995,
#  '10419127': 996,
#  '104196034': 997,
#  '104196234': 998,
#  '104201883': 999,
#  ...}

# %%
fos_matrix
# Out:
# <153247x8956464 sparse matrix of type '<class 'numpy.int64'>'
# 	with 125789134 stored elements in Compressed Sparse Row format>

# %%
print(fos_matrix)
# Out:
#   (0, 0)	88
#   (0, 1)	64
#   (0, 2)	24
#   (0, 3)	14
#   (0, 4)	38
#   (0, 5)	80
#   (0, 6)	32
#   (0, 7)	33
#   (0, 8)	26
#   (0, 9)	133
#   (0, 10)	17
#   (0, 11)	64
#   (0, 12)	48
#   (0, 13)	34
#   (0, 15)	34
#   (0, 16)	60
#   (0, 17)	17
#   (0, 18)	93
#   (0, 19)	28
#   (0, 20)	27
#   (0, 21)	29
#   (0, 22)	25
#   (0, 23)	20
#   (0, 24)	37
#   (0, 25)	13
#   :	:
#   (153246, 264973)	11
#   (153246, 289952)	11
#   (153246, 305295)	11
#   (153246, 365543)	35
#   (153246, 378647)	11
#   (153246, 396136)	17
#   (153246, 398650)	15
#   (153246, 522081)	48
#   (153246, 523629)	16
#   (153246, 584468)	11
#   (153246, 624096)	29
#   (153246, 696572)	25
#   (153246, 836243)	24
#   (153246, 886922)	11
#   (153246, 913500)	14
#   (153246, 1048998)	11
#   (153246, 1086800)	15
#   (153246, 1097751)	17
#   (153246, 1383734)	13
#   (153246, 1387256)	19
#   (153246, 1974659)	12
#   (153246, 2839478)	13
#   (153246, 5424177)	11
#   (153246, 6446782)	17
#   (153246, 6446783)	14

# %%
fos_map["10000559"]
# Out:
# 'Brooks–Iyengar algorithm'
